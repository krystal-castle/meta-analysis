# %%
import PythonMeta as PMA
import pandas as pd
import numpy as np
from scipy import stats

"""
The following three functions were borrowed with adaptations from the sample code by Deng Hongyong
in his description of PythonMeta at https://pypi.org/project/PythonMeta/
"""

def showstudies(studies):     #display table of studies with data
    text = "%-10s %-20s %-20s \n"%("Study ID","Experiment Group","Control Group")
    text += "%-10s %-10s %-10s %-10s %-10s \n"%(" ","e1","n1","e2","n2")
    for i in range(len(studies)):
        text += "%-10s %-10s %-10s %-10s %-10s \n"%(
        studies[i][4],        #study ID
        str(studies[i][0]),   #event num of group1
        str(studies[i][1]),   #total num of group1
        str(studies[i][2]),   #event num of group2
        str(studies[i][3])    #total num of group2
        )
    return text



def showresults(rults):  #display table of meta-analysis results
    text = "%-10s %-6s  %-18s %-10s"%("Study ID","n","OR[95% CI]","Weight(%)\n")    
    for i in range(1,len(rults)):
        text += "%-10s %-6d  %-4.2f[%.2f %.2f]   %6.2f\n"%(   # for each study
        rults[i][0],     #study ID
        rults[i][5],     #total number
        rults[i][1],     #effect size
        rults[i][3],     #lower of CI
        rults[i][4],     #higher of CI
        100*(rults[i][2]/rults[0][2])  #weight
        )
    text += "%-10s %-6d  %-4.2f[%.2f %.2f]   %6d\n"%(         # for the total effect
        "Total OR",      #total effect size name
        rults[0][5],     #total N (all studies)
        rults[0][1],     #total effect size
        rults[0][3],     #total lower CI
        rults[0][4],     #total higher CI
        100
        )  
    text += "%d studies included (N=%d)\n"%(len(rults)-1,rults[0][5])      # associated other statistics
    text += "Heterogeneity: Tau\u00b2=%.3f "%(rults[0][12]) if not rults[0][12]==None else "Heterogeneity: "
    text += "Q(Chisquare)=%.2f(p=%s); I\u00b2=%s\n"%(
        rults[0][7],     #Q test value
        rults[0][8],     #p value for Q test
        str(round(rults[0][9],2))+"%")   #I-square value
    text += "Overall effect test: z=%.2f, p=%s\n"%(rults[0][10],rults[0][11])  #z-test value and p-value

    return text

def main(stys,settings):
    """
    Compute the meta-analysis, display study data and results.
    
    This function sets the parameters of the meta-analysis and computes it. 
    It also displays the table of study data and the results of the meta-analysis by calling showstudies and showresults (defined above).
    
    Parameters
    ----------
    stys : list of str
        Data to be computed.
    settings : dict of {str: str}
        Parameters for the meta-analysis (data type, model, algorithm, and effect size).
    """
    d = PMA.Data()  #Load Data class
    m = PMA.Meta()  #Load Meta class
    f = PMA.Fig()   #Load Fig class

    d.datatype = settings["datatype"]                #set data type, in this case 'CATE' for binary data
    studies = d.getdata(stys)                        #load data
    print(showstudies(studies))                      #show studies table

    m.datatype=d.datatype                            #set data type for meta-analysis calculating
    m.models = settings["models"]                    #set effect models: 'Fixed' or 'Random'
    m.algorithm = settings["algorithm"]              #set algorithm, based on datatype and effect size
    m.effect = settings["effect"]                    #set effect size:RR/OR/RD for binary data; SMD/MD for continuous data
    results = m.meta(studies)                        #perform the analysis
    print(m.models + " " + m.algorithm + " " + m.effect)
    print (showresults(results))                     #show results table

settings = {
    "datatype": "CATE",                             #categorial (binary) data
    "models": "Random",                             #random effects model
    "algorithm": "IV",                              #inverse variance
    "effect": "OR"}                                 #odds ratio

# %%
#Hardy Weinberg Equilibrium Calculations

#Data for each study. Format: [homozygous t/a, heterozygous, homozygous c/g]
Arias_2001 = [30, 81, 53]
Basu_2019 = [27, 41, 12]
Basu_2019_ag = [12, 38, 30]
Bondy_2000 = [27, 58, 40]
Bonnier_2002 = [20, 64, 58]
Bonnier_2002_ag = [20, 64, 58]
Cao_2014 = [129, 120, 51]
Choi_2004 = [39, 82, 27]
Correa_2002 = [15, 27, 10]
Du_2000 = [27, 80, 24]
Frisch_1999 = [46, 77, 49]
Guo_2014 = [19, 29, 22]
Illi_2009 = [45, 181, 169]
Illi_2009_ag = [45, 178, 172]
Kishi_2009 = [220, 386, 196]
Minov_2001 = [26, 56, 39]
Noskova_2009 = [49, 154, 125]
Ohara_1998 = [25, 42, 39]
Oswald_2003 = [31, 71, 40]
Tencomnao_2010 = [116, 64, 3]
Terayama_2003 = [33, 62, 17]
Terayama_2003_ag = [29, 61, 22]
Tsai_1999 = [36, 50, 10]
Yang_2019 = [65, 163, 59]
Yang_2019_ag = [65, 164, 58]
Yusup_2013 = [19, 20, 11]
Yusup_2013_ag = [18, 21, 11]
Zhang_2016 = [251, 420, 171]
Zhang_2016_ag = [166, 423, 251]
Zhang_1997 = [45, 69, 36]

#for loop to calculate HWE
study_names = [Arias_2001, Basu_2019, Basu_2019_ag, Bondy_2000, Bonnier_2002, Bonnier_2002_ag, Cao_2014, Choi_2004, Correa_2002, Du_2000, Frisch_1999, Guo_2014, Illi_2009, Illi_2009_ag, Kishi_2009, Minov_2001, Noskova_2009, Ohara_1998, Oswald_2003, Tencomnao_2010, Terayama_2003, Terayama_2003_ag, Tsai_1999, Yang_2019, Yang_2019_ag, Yusup_2013, Yusup_2013_ag, Zhang_2016, Zhang_2016_ag, Zhang_1997]
study_names_string = ['Arias_2001', 'Basu_2019', 'Basu_2019_ag', 'Bondy_2000', 'Bonnier_2002', 'Bonnier_2002_ag', 'Cao_2014', 'Choi_2004', 'Correa_2002', 'Du_2000', 'Frisch_1999', 'Guo_2014', 'Illi_2009', 'Illi_2009_ag', 'Kishi_2009', 'Minov_2001', 'Noskova_2009', 'Ohara_1998', 'Oswald_2003', 'Tencomnao_2010', 'Terayama_2003', 'Terayama_2003_ag', 'Tsai_1999', 'Yang_2019', 'Yang_2019_ag', 'Yusup_2013', 'Yusup_2013_ag', 'Zhang_2016', 'Zhang_2016_ag', 'Zhang_1997']
expected_values = {}                    #contains the expected values for each study
chi_square_values = {}                  #contains the chi-square values for each study
p_values = {}                           #contains the p-values for each study
for z,y in zip(study_names, study_names_string):
    z_pfreq = (z[0]+z[1]*0.5)/sum(z)    #calculate frequency of t/a allele
    z_qfreq = (z[2]+z[1]*0.5)/sum(z)    #calculate frequency of c/g allele
    z_expected = [(z_pfreq**2)*sum(z), 2*z_pfreq*z_qfreq*sum(z), (z_qfreq**2)*sum(z)]     #calculate expected values for each study
    expected_values[y] = z_expected                                                       #add study name and expected values to dictionary
    z_chi_sqr , z_p = stats.chisquare(f_obs=z, f_exp=z_expected, ddof=1)                  #calculate chi-square and p value for each study
    chi_square_values[y] = z_chi_sqr                                                      #add study name and chi-square value to dictionary
    p_values[y] = z_p                                                                     #add study name and p-value to dictionary
print("Chi Square Values")
print(chi_square_values)
print("P Values")
print(p_values)
# Out:
# Chi Square Values
# {'Arias_2001': 0.009530474518069274, 'Basu_2019': 0.3109836253667492, 'Basu_2019_ag': 3.467164435908082e-05, 'Bondy_2000': 0.4782242331400113, 'Bonnier_2002': 0.11991526042808047, 'Bonnier_2002_ag': 0.11991526042808047, 'Cao_2014': 6.049126898547751, 'Choi_2004': 1.9723464532871984, 'Correa_2002': 0.12056946588433853, 'Du_2000': 6.457072148585431, 'Frisch_1999': 1.8739249746157358, 'Guo_2014': 2.02071358853428, 'Illi_2009': 0.1094275373431545, 'Illi_2009_ag': 0.010579463241945383, 'Kishi_2009': 1.0710240499716321, 'Minov_2001': 0.488994435720177, 'Noskova_2009': 0.01945101000749131, 'Ohara_1998': 3.9679867674858227, 'Oswald_2003': 0.0023099426926628153, 'Tencomnao_2010': 3.116627957245719, 'Terayama_2003': 1.8988715277777795, 'Terayama_2003_ag': 0.9803350359751744, 'Tsai_1999': 1.4789967586066939, 'Yang_2019': 5.338462297333778, 'Yang_2019_ag': 5.913057985098803, 'Yusup_2013': 1.6017266993995385, 'Yusup_2013_ag': 1.025410156571869, 'Zhang_2016': 0.03793917646605952, 'Zhang_2016_ag': 0.2590818696231235, 'Zhang_1997': 0.8818821220867202}
# P Values
# {'Arias_2001': 0.9222307477654216, 'Basu_2019': 0.577077219876637, 'Basu_2019_ag': 0.9953018727940652, 'Bondy_2000': 0.4892277689143397, 'Bonnier_2002': 0.7291264146008496, 'Bonnier_2002_ag': 0.7291264146008496, 'Cao_2014': 0.01391317496787742, 'Choi_2004': 0.16019901931088967, 'Correa_2002': 0.7284176767704849, 'Du_2000': 0.011051158921107708, 'Frisch_1999': 0.17102622348087668, 'Guo_2014': 0.1551662077089355, 'Illi_2009': 0.7407968198802604, 'Illi_2009_ag': 0.9180768484107034, 'Kishi_2009': 0.3007142517093383, 'Minov_2001': 0.4843762068177996, 'Noskova_2009': 0.8890812277824547, 'Ohara_1998': 0.046373184932187436, 'Oswald_2003': 0.9616669398323777, 'Tencomnao_2010': 0.07749700113933702, 'Terayama_2003': 0.1682046853771979, 'Terayama_2003_ag': 0.32211610517677064, 'Tsai_1999': 0.22393155470930176, 'Yang_2019': 0.02085986570027147, 'Yang_2019_ag': 0.015029060869328774, 'Yusup_2013': 0.20565868382231453, 'Yusup_2013_ag': 0.31123913319649354, 'Zhang_2016': 0.8455653246560026, 'Zhang_2016_ag': 0.6107516253389248, 'Zhang_1997': 0.3476866991035813}

# %%
#Calculations for allelic model of rs6313
T_minor_mod1 = [                                      #Values for t minor allele subgroup of rs6313
    "Bondy_2000,95,168,138,250",
#    "Du_2000,140,240,128,262",                        Not in HWE
    "Arias_2001,167,318,187,328",
    "Minov_2001,192,344,134,242",
    "Oswald_2003,138,284,151,284",
    "Illi_2009,109,172,519,790",
    "Guo_2014,80,144,73,140"]
C_minor_mod1 = [                                      #Values for c minor allele subgroup of rs6313
    "Frisch_1999,85,198,175,344",
    "Tsai_1999,62,158,70,192",
    "Correa_2002,73,156,47,104",
    "Terayama_2003,36,74,96,224",
    "Kishi_2009,322,650,778,1604",
    "Yusup_2013,149,390,42,100",
#    "Cao_2015,269,600,222,600",                       Not in HWE
    "Zhang_2016,474,1116,762,1684",
    "Basu_2019,66,160,65,160"
#    "Yang_2019,269,556,281,574"                       Not in HWE
]
Zhang_1997_mod1 = ["Zhang_1997,60,102,141,300"]       #Has no minor allele - complete 50/50 split
T102C_mod1 = T_minor_mod1 + C_minor_mod1 + Zhang_1997_mod1        #All values for rs6313
caucasian_T102C_mod1 = [                              #Values for caucasian subgroup of rs6313
    "Arias_2001,167,318,187,328",
    "Bondy_2000,95,168,138,250",
#    "Du_2000,140,240,128,262",                        Not in HWE
    "Illi_2009,109,172,519,790",
    "Minov_2001,192,344,134,242",
    "Oswald_2003,138,284,151,284"]
asian_T102C_mod1 = [                                  #Values for asian subgroup of rs6313
#    "Cao_2015,269,600,222,600",                       Not in HWE
    "Guo_2014,80,144,73,140",
    "Kishi_2009,322,650,778,1604",
    "Terayama_2003,36,74,96,224",
    "Tsai_1999,62,158,70,192",
#    "Yang_2019,269,556,281,574",                      Not in HWE
    "Zhang_2016,474,1116,762,1684",
    "Zhang_1997,60,102,141,300"]
other_T102C_mod1 = [                                  #Values for other subgroup of rs6313 (not included in final article)
    "Basu_2019,66,160,65,160",
    "Correa_2002,73,156,47,104",
    "Frisch_1999,85,198,175,344",
    "Yusup_2013,149,390,42,100"]
print("T102C Model 1: T vs. C")
main(T102C_mod1, settings)
print("T102C Model 1: T vs. C, with T as minor allele")
main(T_minor_mod1, settings)
print("T102C Model 1: T vs. C, with C as minor allele")
main(C_minor_mod1, settings)
print("T102C Model 1: T vs. C, caucasian subgroup")
main(caucasian_T102C_mod1, settings)
print("T102C Model 1: T vs. C, asian subgroup")
main(asian_T102C_mod1, settings)
print("T102C Model 1: T vs. C, other subgroup")
main(other_T102C_mod1, settings)
# Out:
# T102C Model 1: T vs. C
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bondy_2000 95         168        138        250
# Arias_2001 167        318        187        328
# Minov_2001 192        344        134        242
# Oswald_2003 138        284        151        284
# Illi_2009  109        172        519        790
# Guo_2014   80         144        73         140
# Frisch_1999 85         198        175        344
# Tsai_1999  62         158        70         192
# Correa_2002 73         156        47         104
# Terayama_2003 36         74         96         224
# Kishi_2009 322        650        778        1604
# Yusup_2013 149        390        42         100
# Zhang_2016 474        1116       762        1684
# Basu_2019  66         160        65         160
# Zhang_1997 60         102        141        300
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bondy_2000 418     1.06[0.71 1.57]     4.10
# Arias_2001 646     0.83[0.61 1.14]     6.61
# Minov_2001 586     1.02[0.73 1.42]     5.81
# Oswald_2003 568     0.83[0.60 1.16]     5.87
# Illi_2009  962     0.90[0.64 1.27]     5.40
# Guo_2014   284     1.15[0.72 1.83]     2.92
# Frisch_1999 542     0.73[0.51 1.03]     5.14
# Tsai_1999  350     1.13[0.73 1.74]     3.38
# Correa_2002 260     1.07[0.65 1.76]     2.57
# Terayama_2003 298     1.26[0.75 2.14]     2.29
# Kishi_2009 2254    1.04[0.87 1.25]    19.15
# Yusup_2013 490     0.85[0.55 1.33]     3.19
# Zhang_2016 2800    0.89[0.77 1.04]    27.31
# Basu_2019  320     1.03[0.66 1.60]     3.20
# Zhang_1997 402     1.61[1.02 2.54]     3.08
# Total OR   11180   0.96[0.89 1.04]      100
# 15 studies included (N=11180)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=13.64(p=0.478); I²=0%
# Overall effect test: z=0.95, p=0.343
#
# T102C Model 1: T vs. C, with T as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bondy_2000 95         168        138        250
# Arias_2001 167        318        187        328
# Minov_2001 192        344        134        242
# Oswald_2003 138        284        151        284
# Illi_2009  109        172        519        790
# Guo_2014   80         144        73         140
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bondy_2000 418     1.06[0.71 1.57]    13.35
# Arias_2001 646     0.83[0.61 1.14]    21.53
# Minov_2001 586     1.02[0.73 1.42]    18.92
# Oswald_2003 568     0.83[0.60 1.16]    19.10
# Illi_2009  962     0.90[0.64 1.27]    17.59
# Guo_2014   284     1.15[0.72 1.83]     9.50
# Total OR   3464    0.93[0.81 1.08]      100
# 6 studies included (N=3464)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=2.40(p=0.792); I²=0%
# Overall effect test: z=0.93, p=0.355
#
# T102C Model 1: T vs. C, with C as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Frisch_1999 85         198        175        344
# Tsai_1999  62         158        70         192
# Correa_2002 73         156        47         104
# Terayama_2003 36         74         96         224
# Kishi_2009 322        650        778        1604
# Yusup_2013 149        390        42         100
# Zhang_2016 474        1116       762        1684
# Basu_2019  66         160        65         160
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Frisch_1999 542     0.73[0.51 1.03]     7.76
# Tsai_1999  350     1.13[0.73 1.74]     5.10
# Correa_2002 260     1.07[0.65 1.76]     3.87
# Terayama_2003 298     1.26[0.75 2.14]     3.46
# Kishi_2009 2254    1.04[0.87 1.25]    28.91
# Yusup_2013 490     0.85[0.55 1.33]     4.82
# Zhang_2016 2800    0.89[0.77 1.04]    41.24
# Basu_2019  320     1.03[0.66 1.60]     4.84
# Total OR   7314    0.95[0.86 1.05]      100
# 8 studies included (N=7314)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=6.10(p=0.529); I²=0%
# Overall effect test: z=0.98, p=0.328
#
# T102C Model 1: T vs. C, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 167        318        187        328
# Bondy_2000 95         168        138        250
# Illi_2009  109        172        519        790
# Minov_2001 192        344        134        242
# Oswald_2003 138        284        151        284
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 646     0.83[0.61 1.14]    23.79
# Bondy_2000 418     1.06[0.71 1.57]    14.75
# Illi_2009  962     0.90[0.64 1.27]    19.44
# Minov_2001 586     1.02[0.73 1.42]    20.91
# Oswald_2003 568     0.83[0.60 1.16]    21.11
# Total OR   3180    0.91[0.79 1.06]      100
# 5 studies included (N=3180)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=1.57(p=0.813); I²=0%
# Overall effect test: z=1.16, p=0.248
#
# T102C Model 1: T vs. C, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Guo_2014   80         144        73         140
# Kishi_2009 322        650        778        1604
# Terayama_2003 36         74         96         224
# Tsai_1999  62         158        70         192
# Zhang_2016 474        1116       762        1684
# Zhang_1997 60         102        141        300
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Guo_2014   284     1.15[0.72 1.83]     9.07
# Kishi_2009 2254    1.04[0.87 1.25]    29.84
# Terayama_2003 298     1.26[0.75 2.14]     7.40
# Tsai_1999  350     1.13[0.73 1.74]    10.21
# Zhang_2016 2800    0.89[0.77 1.04]    34.02
# Zhang_1997 402     1.61[1.02 2.54]     9.46
# Total OR   6388    1.06[0.91 1.24]      100
# 6 studies included (N=6388)
# Heterogeneity: Tau²=0.012 Q(Chisquare)=7.86(p=0.171); I²=36.41%
# Overall effect test: z=0.77, p=0.443
#
# T102C Model 1: T vs. C, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  66         160        65         160
# Correa_2002 73         156        47         104
# Frisch_1999 85         198        175        344
# Yusup_2013 149        390        42         100
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  320     1.03[0.66 1.60]    22.73
# Correa_2002 260     1.07[0.65 1.76]    18.20
# Frisch_1999 542     0.73[0.51 1.03]    36.44
# Yusup_2013 490     0.85[0.55 1.33]    22.63
# Total OR   1612    0.87[0.71 1.08]      100
# 4 studies included (N=1612)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=2.18(p=0.537); I²=0%
# Overall effect test: z=1.24, p=0.216

# %%
#Calculations for dominant model of rs6313
T_minor_mod2 = [                                            #Values for t minor allele subgroup of rs6313
    "Arias_2001,124,159,134,164",
    "Bondy_2000,72,84,98,125",
#    "Du_2000,98,120,104,131",                               Not in HWE
    "Guo_2014,54,72,51,70",
    "Illi_2009,75,86,350,395",
    "Minov_2001,141,172,95,121",
    "Oswald_2003,104,142,111,142"]
C_minor_mod2 = [                                            #Values for c minor allele subgroup of rs6313
    "Basu_2019,49,80,53,80",
#    "Cao_2015,207,300,171,300",                             Not in HWE
    "Correa_2002,58,78,37,52",
    "Frisch_1999,65,99,126,172",
    "Kishi_2009,238,325,582,802",
    "Terayama_2003,29,37,79,112",
    "Tsai_1999,53,79,60,96",
#    "Yang_2019,199,278,222,287",                            Not in HWE
    "Yusup_2013,131,195,31,50",
    "Zhang_2016,364,558,591,842"]
Zhang_1997_mod2 = ["Zhang_1997,39,51,105,150"]              #Has no minor allele - complete 50/50 split
T102C_mod2 = T_minor_mod2 + C_minor_mod2 + Zhang_1997_mod2  #All values for rs6313
caucasian_T102C_mod2 = [                                    #Values for caucasian subgroup of rs6313
    "Arias_2001,124,159,134,164",
    "Bondy_2000,72,84,98,125",
#    "Du_2000,98,120,104,131",                               Not in HWE
    "Illi_2009,75,86,350,395",
    "Minov_2001,141,172,95,121",
    "Oswald_2003,104,142,111,142"]
asian_T102C_mod2 = [                                        #Values for asian subgroup of rs6313
#    "Cao_2015,207,300,171,300",                             Not in HWE
    "Guo_2014,54,72,51,70",
    "Kishi_2009,238,325,582,802",
    "Terayama_2003,29,37,79,112",
    "Tsai_1999,53,79,60,96",
#    "Yang_2019,199,278,222,287",                            Not in HWE
    "Zhang_2016,364,558,591,842",
    "Zhang_1997,39,51,105,150"]
other_T102C_mod2 = [                                        #Values for other subgroup of rs6313 (not included in final article)
    "Basu_2019,49,80,53,80",
    "Correa_2002,58,78,37,52",
    "Frisch_1999,65,99,126,172",
    "Yusup_2013,131,195,31,50"]
print('T102C Model 2: TT vs. TC + CC')
main(T102C_mod2, settings)
print('T102C Model 2: TT vs. TC + CC, T as minor allele')
main(T_minor_mod2, settings)
print('T102C Model 2: TT vs. TC + CC, C as minor allele')
main(C_minor_mod2, settings)
print("T102C Model 2: TT vs. TC + CC, caucasian subgroup")
main(caucasian_T102C_mod2, settings)
print("T102C Model 2: TT vs. TC + CC, asian subgroup")
main(asian_T102C_mod2, settings)
print("T102C Model 2: TT vs. TC + CC, other subgroup")
main(other_T102C_mod2, settings)
# Out:
# T102C Model 2: TT vs. TC + CC
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 124        159        134        164
# Bondy_2000 72         84         98         125
# Guo_2014   54         72         51         70
# Illi_2009  75         86         350        395
# Minov_2001 141        172        95         121
# Oswald_2003 104        142        111        142
# Basu_2019  49         80         53         80
# Correa_2002 58         78         37         52
# Frisch_1999 65         99         126        172
# Kishi_2009 238        325        582        802
# Terayama_2003 29         37         79         112
# Tsai_1999  53         79         60         96
# Yusup_2013 131        195        31         50
# Zhang_2016 364        558        591        842
# Zhang_1997 39         51         105        150
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.79[0.46 1.37]     5.43
# Bondy_2000 209     1.65[0.78 3.48]     2.91
# Guo_2014   142     1.12[0.53 2.37]     2.87
# Illi_2009  481     0.88[0.43 1.77]     3.25
# Minov_2001 293     1.24[0.70 2.23]     4.76
# Oswald_2003 284     0.76[0.44 1.32]     5.45
# Basu_2019  160     0.81[0.42 1.54]     3.87
# Correa_2002 130     1.18[0.54 2.58]     2.61
# Frisch_1999 271     0.70[0.41 1.19]     5.65
# Kishi_2009 1127    1.03[0.77 1.38]    19.15
# Terayama_2003 149     1.51[0.63 3.66]     2.08
# Tsai_1999  175     1.22[0.65 2.29]     4.13
# Yusup_2013 245     1.25[0.66 2.39]     3.89
# Zhang_2016 1400    0.80[0.63 1.00]    30.97
# Zhang_1997 201     1.39[0.67 2.91]     2.99
# Total OR   5590    0.95[0.83 1.07]      100
# 15 studies included (N=5590)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=12.08(p=0.600); I²=0%
# Overall effect test: z=0.86, p=0.389
#
# T102C Model 2: TT vs. TC + CC, T as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 124        159        134        164
# Bondy_2000 72         84         98         125
# Guo_2014   54         72         51         70
# Illi_2009  75         86         350        395
# Minov_2001 141        172        95         121
# Oswald_2003 104        142        111        142
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.79[0.46 1.37]    22.01
# Bondy_2000 209     1.65[0.78 3.48]    11.80
# Guo_2014   142     1.12[0.53 2.37]    11.65
# Illi_2009  481     0.88[0.43 1.77]    13.18
# Minov_2001 293     1.24[0.70 2.23]    19.29
# Oswald_2003 284     0.76[0.44 1.32]    22.08
# Total OR   1732    0.99[0.76 1.27]      100
# 6 studies included (N=1732)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=4.13(p=0.532); I²=0%
# Overall effect test: z=0.10, p=0.920
#
# T102C Model 2: TT vs. TC + CC, C as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  49         80         53         80
# Correa_2002 58         78         37         52
# Frisch_1999 65         99         126        172
# Kishi_2009 238        325        582        802
# Terayama_2003 29         37         79         112
# Tsai_1999  53         79         60         96
# Yusup_2013 131        195        31         50
# Zhang_2016 364        558        591        842
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.81[0.42 1.54]     5.35
# Correa_2002 130     1.18[0.54 2.58]     3.61
# Frisch_1999 271     0.70[0.41 1.19]     7.80
# Kishi_2009 1127    1.03[0.77 1.38]    26.47
# Terayama_2003 149     1.51[0.63 3.66]     2.87
# Tsai_1999  175     1.22[0.65 2.29]     5.71
# Yusup_2013 245     1.25[0.66 2.39]     5.37
# Zhang_2016 1400    0.80[0.63 1.00]    42.81
# Total OR   3657    0.92[0.79 1.06]      100
# 8 studies included (N=3657)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=6.62(p=0.471); I²=0%
# Overall effect test: z=1.14, p=0.260
#
# T102C Model 2: TT vs. TC + CC, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 124        159        134        164
# Bondy_2000 72         84         98         125
# Illi_2009  75         86         350        395
# Minov_2001 141        172        95         121
# Oswald_2003 104        142        111        142
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.79[0.46 1.37]    24.90
# Bondy_2000 209     1.65[0.78 3.48]    13.36
# Illi_2009  481     0.88[0.43 1.77]    14.93
# Minov_2001 293     1.24[0.70 2.23]    21.83
# Oswald_2003 284     0.76[0.44 1.32]    24.98
# Total OR   1590    0.97[0.74 1.28]      100
# 5 studies included (N=1590)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=4.01(p=0.405); I²=0.23%
# Overall effect test: z=0.21, p=0.832
#
# T102C Model 2: TT vs. TC + CC, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Guo_2014   54         72         51         70
# Kishi_2009 238        325        582        802
# Terayama_2003 29         37         79         112
# Tsai_1999  53         79         60         96
# Zhang_2016 364        558        591        842
# Zhang_1997 39         51         105        150
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Guo_2014   142     1.12[0.53 2.37]     5.65
# Kishi_2009 1127    1.03[0.77 1.38]    31.29
# Terayama_2003 149     1.51[0.63 3.66]     4.13
# Tsai_1999  175     1.22[0.65 2.29]     8.00
# Zhang_2016 1400    0.80[0.63 1.00]    45.06
# Zhang_1997 201     1.39[0.67 2.91]     5.87
# Total OR   3194    0.97[0.81 1.16]      100
# 6 studies included (N=3194)
# Heterogeneity: Tau²=0.005 Q(Chisquare)=5.52(p=0.358); I²=9.48%
# Overall effect test: z=0.35, p=0.723
#
# T102C Model 2: TT vs. TC + CC, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  49         80         53         80
# Correa_2002 58         78         37         52
# Frisch_1999 65         99         126        172
# Yusup_2013 131        195        31         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.81[0.42 1.54]    24.18
# Correa_2002 130     1.18[0.54 2.58]    16.31
# Frisch_1999 271     0.70[0.41 1.19]    35.24
# Yusup_2013 245     1.25[0.66 2.39]    24.27
# Total OR   806     0.91[0.66 1.25]      100
# 4 studies included (N=806)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=2.44(p=0.487); I²=0%
# Overall effect test: z=0.60, p=0.548

# %%
#Calculations for recessive model of rs6313
T_minor_mod3 = [                                             #Values for t minor allele subgroup of rs6313
    "Arias_2001,43,159,53,164",
    "Bondy_2000,23,84,40,125",
#    "Du_2000,42,120,24,131",                                 Not in HWE
    "Guo_2014,26,72,22,70",
    "Illi_2009,34,86,169,395",
    "Minov_2001,51,172,39,121",
    "Oswald_2003,34,142,40,142"]
C_minor_mod3 = [                                             #Values for c minor allele subgroup of rs6313
    "Basu_2019,17,80,12,80",
#    "Cao_2015,62,300,51,300",                                Not in HWE
    "Correa_2002,15,78,10,52",
    "Frisch_1999,20,99,49,172",
    "Kishi_2009,84,325,196,802",
    "Terayama_2003,7,37,17,112",
    "Tsai_1999,9,79,10,96",
#    "Yang_2019,70,278,59,287",                               Not in HWE
    "Yusup_2013,18,195,11,50",
    "Zhang_2016,110,558,171,842"]
Zhang_1997_mod3 = ["Zhang_1997,21,51,36,150"]                #Has no minor allele - complete 50/50 split
T102C_mod3 = T_minor_mod3 + C_minor_mod3 + Zhang_1997_mod3   #All values for rs6313
caucasian_T102C_mod3 = [                                     #Values for caucasian subgroup of rs6313
    "Arias_2001,43,159,53,164",
    "Bondy_2000,23,84,40,125",
#    "Du_2000,42,120,24,131",                                 Not in HWE
    "Illi_2009,34,86,169,395",
    "Minov_2001,51,172,39,121",
    "Oswald_2003,34,142,40,142"]
asian_T102C_mod3 = [                                         #Values for asian subgroup of rs6313
    "Zhang_1997,21,51,36,150",
    "Tsai_1999,9,79,10,96",
    "Terayama_2003,7,37,17,112",
    "Kishi_2009,84,325,196,802",
    "Guo_2014,26,72,22,70",
#    "Cao_2015,62,300,51,300",                                Not in HWE
    "Zhang_2016,110,558,171,842"
#    "Yang_2019,70,278,59,287"                                Not in HWE
]
other_T102C_mod3 = [                                         #Values for other subgroup of rs6313 (not included in final article)
    "Basu_2019,17,80,12,80",
    "Correa_2002,15,78,10,52",
    "Frisch_1999,20,99,49,172",
    "Yusup_2013,18,195,11,50"]
print('T102C Model 3: TT + TC vs. CC')
main(T102C_mod3, settings)
print('T102C Model 3: TT + TC vs. CC, T as minor allele')
main(T_minor_mod3, settings)
print('T102C Model 3: TT + TC vs. CC, C as minor allele')
main(C_minor_mod3, settings)
print("T102C Model 3: TT + TC vs. CC, caucasian subgroup")
main(caucasian_T102C_mod3, settings)
print("T102C Model 3: TT + TC vs. CC, asian subgroup")
main(asian_T102C_mod3, settings)
print("T102C Model 3: TT + TC vs. CC, other subgroup")
main(other_T102C_mod3, settings)
# Out:
# T102C Model 3: TT + TC vs. CC
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         159        53         164
# Bondy_2000 23         84         40         125
# Guo_2014   26         72         22         70
# Illi_2009  34         86         169        395
# Minov_2001 51         172        39         121
# Oswald_2003 34         142        40         142
# Basu_2019  17         80         12         80
# Correa_2002 15         78         10         52
# Frisch_1999 20         99         49         172
# Kishi_2009 84         325        196        802
# Terayama_2003 7          37         17         112
# Tsai_1999  9          79         10         96
# Yusup_2013 18         195        11         50
# Zhang_2016 110        558        171        842
# Zhang_1997 21         51         36         150
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.78[0.48 1.25]     8.31
# Bondy_2000 209     0.80[0.44 1.47]     5.67
# Guo_2014   142     1.23[0.61 2.48]     4.51
# Illi_2009  481     0.87[0.54 1.41]     8.39
# Minov_2001 293     0.89[0.54 1.46]     7.73
# Oswald_2003 284     0.80[0.47 1.37]     7.08
# Basu_2019  160     1.53[0.68 3.45]     3.43
# Correa_2002 130     1.00[0.41 2.44]     2.92
# Frisch_1999 271     0.64[0.35 1.15]     5.95
# Kishi_2009 1127    1.08[0.80 1.45]    15.56
# Terayama_2003 149     1.30[0.49 3.44]     2.49
# Tsai_1999  175     1.11[0.43 2.87]     2.57
# Yusup_2013 245     0.36[0.16 0.82]     3.34
# Zhang_2016 1400    0.96[0.74 1.26]    17.25
# Zhang_1997 201     2.22[1.13 4.34]     4.81
# Total OR   5590    0.95[0.81 1.11]      100
# 15 studies included (N=5590)
# Heterogeneity: Tau²=0.020 Q(Chisquare)=17.79(p=0.218); I²=21.32%
# Overall effect test: z=0.67, p=0.505
#
# T102C Model 3: TT + TC vs. CC, T as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         159        53         164
# Bondy_2000 23         84         40         125
# Guo_2014   26         72         22         70
# Illi_2009  34         86         169        395
# Minov_2001 51         172        39         121
# Oswald_2003 34         142        40         142
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.78[0.48 1.25]    20.72
# Bondy_2000 209     0.80[0.44 1.47]    12.81
# Guo_2014   142     1.23[0.61 2.48]     9.79
# Illi_2009  481     0.87[0.54 1.41]    20.99
# Minov_2001 293     0.89[0.54 1.46]    18.84
# Oswald_2003 284     0.80[0.47 1.37]    16.85
# Total OR   1732    0.86[0.69 1.07]      100
# 6 studies included (N=1732)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=1.34(p=0.917); I²=0%
# Overall effect test: z=1.33, p=0.186
#
# T102C Model 3: TT + TC vs. CC, C as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  17         80         12         80
# Correa_2002 15         78         10         52
# Frisch_1999 20         99         49         172
# Kishi_2009 84         325        196        802
# Terayama_2003 7          37         17         112
# Tsai_1999  9          79         10         96
# Yusup_2013 18         195        11         50
# Zhang_2016 110        558        171        842
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     1.53[0.68 3.45]     6.95
# Correa_2002 130     1.00[0.41 2.44]     5.95
# Frisch_1999 271     0.64[0.35 1.15]    11.75
# Kishi_2009 1127    1.08[0.80 1.45]    27.84
# Terayama_2003 149     1.30[0.49 3.44]     5.10
# Tsai_1999  175     1.11[0.43 2.87]     5.26
# Yusup_2013 245     0.36[0.16 0.82]     6.78
# Zhang_2016 1400    0.96[0.74 1.26]    30.36
# Total OR   3657    0.94[0.74 1.18]      100
# 8 studies included (N=3657)
# Heterogeneity: Tau²=0.027 Q(Chisquare)=9.58(p=0.216); I²=26.9%
# Overall effect test: z=0.55, p=0.584
#
# T102C Model 3: TT + TC vs. CC, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         159        53         164
# Bondy_2000 23         84         40         125
# Illi_2009  34         86         169        395
# Minov_2001 51         172        39         121
# Oswald_2003 34         142        40         142
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 323     0.78[0.48 1.25]    22.97
# Bondy_2000 209     0.80[0.44 1.47]    14.20
# Illi_2009  481     0.87[0.54 1.41]    23.27
# Minov_2001 293     0.89[0.54 1.46]    20.89
# Oswald_2003 284     0.80[0.47 1.37]    18.68
# Total OR   1590    0.83[0.66 1.04]      100
# 5 studies included (N=1590)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=0.21(p=0.981); I²=0%
# Overall effect test: z=1.60, p=0.113
#
# T102C Model 3: TT + TC vs. CC, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Zhang_1997 21         51         36         150
# Tsai_1999  9          79         10         96
# Terayama_2003 7          37         17         112
# Kishi_2009 84         325        196        802
# Guo_2014   26         72         22         70
# Zhang_2016 110        558        171        842
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Zhang_1997 201     2.22[1.13 4.34]     7.88
# Tsai_1999  175     1.11[0.43 2.87]     3.98
# Terayama_2003 149     1.30[0.49 3.44]     3.84
# Kishi_2009 1127    1.08[0.80 1.45]    35.31
# Guo_2014   142     1.23[0.61 2.48]     7.34
# Zhang_2016 1400    0.96[0.74 1.26]    41.66
# Total OR   3194    1.11[0.91 1.34]      100
# 6 studies included (N=3194)
# Heterogeneity: Tau²=0.004 Q(Chisquare)=5.36(p=0.376); I²=6.68%
# Overall effect test: z=1.05, p=0.293
#
# T102C Model 3: TT + TC vs. CC, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  17         80         12         80
# Correa_2002 15         78         10         52
# Frisch_1999 20         99         49         172
# Yusup_2013 18         195        11         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     1.53[0.68 3.45]    23.84
# Correa_2002 130     1.00[0.41 2.44]    21.80
# Frisch_1999 271     0.64[0.35 1.15]    30.84
# Yusup_2013 245     0.36[0.16 0.82]    23.51
# Total OR   806     0.76[0.43 1.34]      100
# 4 studies included (N=806)
# Heterogeneity: Tau²=0.187 Q(Chisquare)=6.65(p=0.084); I²=54.9%
# Overall effect test: z=0.95, p=0.344

# %%
#Calculations for homozygous model of rs6313
T_minor_mod4 = [                                                 #Values for t minor allele subgroup of rs6313
    "Arias_2001,43,78,53,83",
    "Bondy_2000,23,35,40,67",
#    "Du_2000,42,64,24,51",                                       Not in HWE
    "Guo_2014,26,44,22,41",
    "Illi_2009,34,45,169,214",
    "Minov_2001,51,82,39,65",
    "Oswald_2003,34,72,40,71"]
C_minor_mod4 = [                                                 #Values for c minor allele subgroup of rs6313
    "Basu_2019,17,48,12,39",
#    "Cao_2015,62,155,51,180",                                    Not in HWE
    "Correa_2002,15,35,10,25",
    "Frisch_1999,20,54,49,95",
    "Kishi_2009,84,171,196,416",
    "Terayama_2003,7,15,17,50",
    "Tsai_1999,9,35,10,46",
#    "Yang_2019,70,149,59,124",                                   Not in HWE
    "Yusup_2013,18,82,11,30",
    "Zhang_2016,110,304,171,422"]
Zhang_1997_mod4 = ["Zhang_1997,21,33,36,81"]                     #Has no minor allele - complete 50/50 split
T102C_mod4 = T_minor_mod4 + C_minor_mod4 + Zhang_1997_mod4       #All values for rs6313
caucasian_T102C_mod4 = [                                         #Values for caucasian subgroup of rs6313
    "Arias_2001,43,78,53,83",
    "Bondy_2000,23,35,40,67",
#    "Du_2000,42,64,24,51",                                       Not in HWE
    "Illi_2009,34,45,169,214",
    "Minov_2001,51,82,39,65",
    "Oswald_2003,34,72,40,71"]
asian_T102C_mod4 = [                                             #Values for asian subgroup of rs6313
#    "Cao_2015,62,155,51,180",                                    Not in HWE
    "Guo_2014,26,44,22,41",
    "Kishi_2009,84,171,196,416",
    "Terayama_2003,7,15,17,50",
    "Tsai_1999,9,35,10,46",
#    "Yang_2019,70,149,59,124",                                   Not in HWE
    "Zhang_2016,110,304,171,422",
    "Zhang_1997,21,33,36,81"]
other_T102C_mod4 = [                                             #Values for other subgroup of rs6313 (not included in final article)
    "Basu_2019,17,48,12,39",
    "Correa_2002,15,35,10,25",
    "Frisch_1999,20,54,49,95",
    "Yusup_2013,18,82,11,30",]
print('T102C Model 4: TT vs. CC')
main(T102C_mod4, settings)
print('T102C Model 4: TT vs. CC, T as minor allele')
main(T_minor_mod4, settings)
print('T102C Model 4: TT vs. CC, C as minor allele')
main(C_minor_mod4, settings)
print("T102C Model 4: TT vs. CC, caucasian subgroup")
main(caucasian_T102C_mod4, settings)
print("T102C Model 4: TT vs. CC, asian subgroup")
main(asian_T102C_mod4, settings)
print("T102C Model 4: TT vs. CC, other subgroup")
main(other_T102C_mod4, settings)
# Out:
# T102C Model 4: TT vs. CC
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         78         53         83
# Bondy_2000 23         35         40         67
# Guo_2014   26         44         22         41
# Illi_2009  34         45         169        214
# Minov_2001 51         82         39         65
# Oswald_2003 34         72         40         71
# Basu_2019  17         48         12         39
# Correa_2002 15         35         10         25
# Frisch_1999 20         54         49         95
# Kishi_2009 84         171        196        416
# Terayama_2003 7          15         17         50
# Tsai_1999  9          35         10         46
# Yusup_2013 18         82         11         30
# Zhang_2016 110        304        171        422
# Zhang_1997 21         33         36         81
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 161     0.70[0.37 1.31]     6.57
# Bondy_2000 102     1.29[0.55 3.03]     3.65
# Guo_2014   85      1.25[0.53 2.95]     3.58
# Illi_2009  259     0.82[0.39 1.75]     4.63
# Minov_2001 147     1.10[0.56 2.14]     5.90
# Oswald_2003 143     0.69[0.36 1.34]     6.06
# Basu_2019  87      1.23[0.50 3.04]     3.26
# Correa_2002 60      1.12[0.40 3.19]     2.44
# Frisch_1999 149     0.55[0.28 1.09]     5.63
# Kishi_2009 587     1.08[0.76 1.55]    19.96
# Terayama_2003 65      1.70[0.53 5.48]     1.94
# Tsai_1999  81      1.25[0.44 3.50]     2.49
# Yusup_2013 112     0.49[0.20 1.20]     3.21
# Zhang_2016 726     0.83[0.61 1.13]    26.89
# Zhang_1997 114     2.19[0.95 5.04]     3.80
# Total OR   2878    0.94[0.79 1.10]      100
# 15 studies included (N=2878)
# Heterogeneity: Tau²=0.002 Q(Chisquare)=14.23(p=0.434); I²=1.59%
# Overall effect test: z=0.80, p=0.423
#
# T102C Model 4: TT vs. CC, T as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         78         53         83
# Bondy_2000 23         35         40         67
# Guo_2014   26         44         22         41
# Illi_2009  34         45         169        214
# Minov_2001 51         82         39         65
# Oswald_2003 34         72         40         71
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 161     0.70[0.37 1.31]    21.69
# Bondy_2000 102     1.29[0.55 3.03]    11.95
# Guo_2014   85      1.25[0.53 2.95]    11.74
# Illi_2009  259     0.82[0.39 1.75]    15.20
# Minov_2001 147     1.10[0.56 2.14]    19.45
# Oswald_2003 143     0.69[0.36 1.34]    19.97
# Total OR   897     0.90[0.67 1.21]      100
# 6 studies included (N=897)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=2.88(p=0.718); I²=0%
# Overall effect test: z=0.71, p=0.478
#
# T102C Model 4: TT vs. CC, C as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  17         48         12         39
# Correa_2002 15         35         10         25
# Frisch_1999 20         54         49         95
# Kishi_2009 84         171        196        416
# Terayama_2003 7          15         17         50
# Tsai_1999  9          35         10         46
# Yusup_2013 18         82         11         30
# Zhang_2016 110        304        171        422
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  87      1.23[0.50 3.04]     5.04
# Correa_2002 60      1.12[0.40 3.19]     3.77
# Frisch_1999 149     0.55[0.28 1.09]     8.69
# Kishi_2009 587     1.08[0.76 1.55]    30.26
# Terayama_2003 65      1.70[0.53 5.48]     3.00
# Tsai_1999  81      1.25[0.44 3.50]     3.85
# Yusup_2013 112     0.49[0.20 1.20]     4.96
# Zhang_2016 726     0.83[0.61 1.13]    40.43
# Total OR   1867    0.91[0.74 1.11]      100
# 8 studies included (N=1867)
# Heterogeneity: Tau²=0.003 Q(Chisquare)=7.19(p=0.410); I²=2.58%
# Overall effect test: z=0.94, p=0.348
#
# T102C Model 4: TT vs. CC, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Arias_2001 43         78         53         83
# Bondy_2000 23         35         40         67
# Illi_2009  34         45         169        214
# Minov_2001 51         82         39         65
# Oswald_2003 34         72         40         71
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Arias_2001 161     0.70[0.37 1.31]    24.57
# Bondy_2000 102     1.29[0.55 3.03]    13.54
# Illi_2009  259     0.82[0.39 1.75]    17.22
# Minov_2001 147     1.10[0.56 2.14]    22.04
# Oswald_2003 143     0.69[0.36 1.34]    22.63
# Total OR   812     0.86[0.63 1.18]      100
# 5 studies included (N=812)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=2.25(p=0.690); I²=0%
# Overall effect test: z=0.94, p=0.349
#
# T102C Model 4: TT vs. CC, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Guo_2014   26         44         22         41
# Kishi_2009 84         171        196        416
# Terayama_2003 7          15         17         50
# Tsai_1999  9          35         10         46
# Zhang_2016 110        304        171        422
# Zhang_1997 21         33         36         81
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Guo_2014   85      1.25[0.53 2.95]     8.16
# Kishi_2009 587     1.08[0.76 1.55]    32.99
# Terayama_2003 65      1.70[0.53 5.48]     4.59
# Tsai_1999  81      1.25[0.44 3.50]     5.82
# Zhang_2016 726     0.83[0.61 1.13]    39.82
# Zhang_1997 114     2.19[0.95 5.04]     8.62
# Total OR   1658    1.08[0.83 1.40]      100
# 6 studies included (N=1658)
# Heterogeneity: Tau²=0.019 Q(Chisquare)=6.12(p=0.295); I²=18.34%
# Overall effect test: z=0.58, p=0.564
#
# T102C Model 4: TT vs. CC, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  17         48         12         39
# Correa_2002 15         35         10         25
# Frisch_1999 20         54         49         95
# Yusup_2013 18         82         11         30
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  87      1.23[0.50 3.04]    22.89
# Correa_2002 60      1.12[0.40 3.19]    17.55
# Frisch_1999 149     0.55[0.28 1.09]    36.98
# Yusup_2013 112     0.49[0.20 1.20]    22.58
# Total OR   408     0.73[0.46 1.15]      100
# 4 studies included (N=408)
# Heterogeneity: Tau²=0.025 Q(Chisquare)=3.37(p=0.340); I²=11.1%
# Overall effect test: z=1.35, p=0.181

# %%
#Calculations for allelic model of rs6311
A_minor_mod1 = [                                 #Values for a minor allele subgroup of rs6311
    "Basu_2019,94,160,98,160",
    "Bonnier_2002,76,130,180,284",
    "Choi_2004,213,378,136,296",
    "Illi_2009,109,172,522,790",
    "Noskova_2009,239,348,404,656",
#    "Ohara_1998,64,134,120,212",                 Not in HWE
    "Zhang_2016,620,1092,925,1680"]
G_minor_mod1 = [                                 #Values for g minor allele subgroup of rs6311
    "Tencomnao_2010,71,360,70,366",
    "Terayama_2003,44,78,105,224",
#    "Yang_2019,264,556,280,574",                 Not in HWE
    "Yusup_2013,152,390,43,100"]
A1438G_mod1 = A_minor_mod1 + G_minor_mod1
caucasian_A1438G_mod1 = [                        #Values for caucasian subgroup of rs6311
    "Bonnier_2002,76,130,180,284",
    "Illi_2009,109,172,522,790",
    "Noskova_2009,239,348,404,656"]
asian_A1438G_mod1 = [                            #Values for asian subgroup of rs6311
    "Choi_2004,213,378,136,296",
#    "Ohara_1998,64,134,120,212",                 Not in HWE
    "Zhang_2016,620,1092,925,1680",
    "Tencomnao_2010,71,360,70,366",
    "Terayama_2003,44,78,105,224"
#    "Yang_2019,264,556,280,574"                  Not in HWE
]
other_A1438G_mod1 = [                            #Values for other subgroup of rs6311 (not included in final article)
    "Basu_2019,94,160,98,160",
    "Yusup_2013,152,390,43,100"]
print("A-1438G Model 1: A vs. G")
main(A1438G_mod1, settings)
print("A-1438G Model 1: A vs. G, A as minor allele")
main(A_minor_mod1, settings)
print("A-1438G Model 1: A vs. G, G as minor allele")
main(G_minor_mod1, settings)
print("A-1438G Model 1: A vs. G, caucasian subgroup")
main(caucasian_A1438G_mod1, settings)
print("A-1438G Model 1: A vs. G, asian subgroup")
main(asian_A1438G_mod1, settings)
print("A-1438G Model 1: A vs. G, other subgroup")
main(other_A1438G_mod1, settings)
# Out:
# A-1438G Model 1: A vs. G
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  94         160        98         160
# Bonnier_2002 76         130        180        284
# Choi_2004  213        378        136        296
# Illi_2009  109        172        522        790
# Noskova_2009 239        348        404        656
# Zhang_2016 620        1092       925        1680
# Tencomnao_2010 71         360        70         366
# Terayama_2003 44         78         105        224
# Yusup_2013 152        390        43         100
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  320     0.90[0.58 1.41]     7.69
# Bonnier_2002 414     0.81[0.53 1.24]     8.31
# Choi_2004  674     1.52[1.12 2.06]    12.68
# Illi_2009  962     0.89[0.63 1.25]    11.05
# Noskova_2009 1004    1.37[1.04 1.80]    14.19
# Zhang_2016 2772    1.07[0.92 1.25]    22.08
# Tencomnao_2010 726     1.04[0.72 1.50]    10.12
# Terayama_2003 302     1.47[0.87 2.46]     6.13
# Yusup_2013 490     0.85[0.54 1.32]     7.75
# Total OR   7664    1.09[0.95 1.26]      100
# 9 studies included (N=7664)
# Heterogeneity: Tau²=0.018 Q(Chisquare)=13.58(p=0.094); I²=41.08%
# Overall effect test: z=1.21, p=0.230
#
# A-1438G Model 1: A vs. G, A as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  94         160        98         160
# Bonnier_2002 76         130        180        284
# Choi_2004  213        378        136        296
# Illi_2009  109        172        522        790
# Noskova_2009 239        348        404        656
# Zhang_2016 620        1092       925        1680
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  320     0.90[0.58 1.41]    10.95
# Bonnier_2002 414     0.81[0.53 1.24]    11.75
# Choi_2004  674     1.52[1.12 2.06]    16.98
# Illi_2009  962     0.89[0.63 1.25]    15.09
# Noskova_2009 1004    1.37[1.04 1.80]    18.66
# Zhang_2016 2772    1.07[0.92 1.25]    26.57
# Total OR   6146    1.10[0.92 1.32]      100
# 6 studies included (N=6146)
# Heterogeneity: Tau²=0.026 Q(Chisquare)=10.95(p=0.053); I²=54.34%
# Overall effect test: z=1.02, p=0.309
#
# A-1438G Model 1: A vs. G, G as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Tencomnao_2010 71         360        70         366
# Terayama_2003 44         78         105        224
# Yusup_2013 152        390        43         100
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Tencomnao_2010 726     1.04[0.72 1.50]    43.07
# Terayama_2003 302     1.47[0.87 2.46]    24.88
# Yusup_2013 490     0.85[0.54 1.32]    32.06
# Total OR   1518    1.06[0.80 1.40]      100
# 3 studies included (N=1518)
# Heterogeneity: Tau²=0.012 Q(Chisquare)=2.49(p=0.289); I²=19.84%
# Overall effect test: z=0.41, p=0.684
#
# A-1438G Model 1: A vs. G, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bonnier_2002 76         130        180        284
# Illi_2009  109        172        522        790
# Noskova_2009 239        348        404        656
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bonnier_2002 414     0.81[0.53 1.24]    28.31
# Illi_2009  962     0.89[0.63 1.25]    33.49
# Noskova_2009 1004    1.37[1.04 1.80]    38.20
# Total OR   2380    1.02[0.73 1.43]      100
# 3 studies included (N=2380)
# Heterogeneity: Tau²=0.058 Q(Chisquare)=5.78(p=0.056); I²=65.38%
# Overall effect test: z=0.12, p=0.901
#
# A-1438G Model 1: A vs. G, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Choi_2004  213        378        136        296
# Zhang_2016 620        1092       925        1680
# Tencomnao_2010 71         360        70         366
# Terayama_2003 44         78         105        224
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Choi_2004  674     1.52[1.12 2.06]    24.59
# Zhang_2016 2772    1.07[0.92 1.25]    44.39
# Tencomnao_2010 726     1.04[0.72 1.50]    19.43
# Terayama_2003 302     1.47[0.87 2.46]    11.60
# Total OR   4474    1.20[0.99 1.47]      100
# 4 studies included (N=4474)
# Heterogeneity: Tau²=0.016 Q(Chisquare)=5.11(p=0.171); I²=41.32%
# Overall effect test: z=1.85, p=0.064
#
# A-1438G Model 1: A vs. G, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  94         160        98         160
# Yusup_2013 152        390        43         100
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  320     0.90[0.58 1.41]    49.74
# Yusup_2013 490     0.85[0.54 1.32]    50.26
# Total OR   810     0.87[0.64 1.20]      100
# 2 studies included (N=810)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=0.04(p=0.855); I²=0%
# Overall effect test: z=0.84, p=0.400

# %%
#Calculations for dominant model of rs6311
A_minor_mod2 = [                                    #Values for a minor allele subgroup of rs6311
    "Basu_2019,65,80,68,80",
    "Bonnier_2002,55,65,122,142",
    "Choi_2004,165,189,109,148",
    "Illi_2009,75,86,350,395",
    "Noskova_2009,157,174,279,328",
#    "Ohara_1998,47,67,81,106",                      Not in HWE
    "Zhang_2016,437,546,674,840"]
G_minor_mod2 = [                                    #Values for g minor allele subgroup of rs6311
    "Tencomnao_2010,70,180,67,183",
    "Terayama_2003,30,39,83,112",
#    "Yang_2019,196,278,222,287",                    Not in HWE
    "Yusup_2013,132,195,32,50"]
caucasian_A1438G_mod2 = [                           #Values for caucasian subgroup of rs6311
    "Bonnier_2002,55,65,122,142",
    "Illi_2009,75,86,350,395",
    "Noskova_2009,157,174,279,328"]
asian_A1438G_mod2 = [                               #Values for asian subgroup of rs6311
    "Choi_2004,165,189,109,148",
#    "Ohara_1998,47,67,81,106",                      Not in HWE
    "Zhang_2016,437,546,674,840",
    "Tencomnao_2010,70,180,67,183",
    "Terayama_2003,30,39,83,112"
#    "Yang_2019,196,278,222,287"                     Not in HWE
]
other_A1438G_mod2 = [                               #Values for other subgroup of rs6311 (not included in final article)
    "Basu_2019,65,80,68,80",
    "Yusup_2013,132,195,32,50"]
A1438G_mod2 = A_minor_mod2 + G_minor_mod2
print("A-1438G Model 2: AA vs. AG + GG")
main(A1438G_mod2, settings)
print("A-1438G Model 2: AA vs. AG + GG, A as minor allele")
main(A_minor_mod2, settings)
print("A-1438G Model 2: AA vs. AG + GG, G as minor allele")
main(G_minor_mod2, settings)
print("A-1438G Model 2: AA vs. AG + GG, caucasian subgroup")
main(caucasian_A1438G_mod2, settings)
print("A-1438G Model 2: AA vs. AG + GG, asian subgroup")
main(asian_A1438G_mod2, settings)
print("A-1438G Model 2: AA vs. AG + GG, other subgroup")
main(other_A1438G_mod2, settings)
# Out:
# A-1438G Model 2: AA vs. AG + GG
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  65         80         68         80
# Bonnier_2002 55         65         122        142
# Choi_2004  165        189        109        148
# Illi_2009  75         86         350        395
# Noskova_2009 157        174        279        328
# Zhang_2016 437        546        674        840
# Tencomnao_2010 70         180        67         183
# Terayama_2003 30         39         83         112
# Yusup_2013 132        195        32         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.76[0.33 1.76]     6.22
# Bonnier_2002 207     0.90[0.40 2.05]     6.33
# Choi_2004  337     2.46[1.40 4.32]    11.45
# Illi_2009  481     0.88[0.43 1.77]     8.16
# Noskova_2009 502     1.62[0.90 2.91]    10.83
# Zhang_2016 1386    0.99[0.75 1.29]    25.32
# Tencomnao_2010 363     1.10[0.72 1.68]    16.52
# Terayama_2003 151     1.16[0.49 2.74]     5.92
# Yusup_2013 245     1.18[0.61 2.26]     9.24
# Total OR   3832    1.17[0.93 1.47]      100
# 9 studies included (N=3832)
# Heterogeneity: Tau²=0.033 Q(Chisquare)=11.42(p=0.183); I²=29.92%
# Overall effect test: z=1.37, p=0.174
#
# A-1438G Model 2: AA vs. AG + GG, A as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  65         80         68         80
# Bonnier_2002 55         65         122        142
# Choi_2004  165        189        109        148
# Illi_2009  75         86         350        395
# Noskova_2009 157        174        279        328
# Zhang_2016 437        546        674        840
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.76[0.33 1.76]    11.71
# Bonnier_2002 207     0.90[0.40 2.05]    11.86
# Choi_2004  337     2.46[1.40 4.32]    17.84
# Illi_2009  481     0.88[0.43 1.77]    14.26
# Noskova_2009 502     1.62[0.90 2.91]    17.23
# Zhang_2016 1386    0.99[0.75 1.29]    27.10
# Total OR   3073    1.19[0.84 1.71]      100
# 6 studies included (N=3073)
# Heterogeneity: Tau²=0.104 Q(Chisquare)=11.38(p=0.045); I²=56.06%
# Overall effect test: z=0.98, p=0.331
#
# A-1438G Model 2: AA vs. AG + GG, G as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Tencomnao_2010 70         180        67         183
# Terayama_2003 30         39         83         112
# Yusup_2013 132        195        32         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Tencomnao_2010 363     1.10[0.72 1.68]    59.83
# Terayama_2003 151     1.16[0.49 2.74]    14.70
# Yusup_2013 245     1.18[0.61 2.26]    25.46
# Total OR   759     1.13[0.81 1.57]      100
# 3 studies included (N=759)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=0.03(p=0.984); I²=0%
# Overall effect test: z=0.73, p=0.467
#
# A-1438G Model 2: AA vs. AG + GG, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bonnier_2002 55         65         122        142
# Illi_2009  75         86         350        395
# Noskova_2009 157        174        279        328
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bonnier_2002 207     0.90[0.40 2.05]    23.98
# Illi_2009  481     0.88[0.43 1.77]    31.84
# Noskova_2009 502     1.62[0.90 2.91]    44.18
# Total OR   1190    1.16[0.76 1.76]      100
# 3 studies included (N=1190)
# Heterogeneity: Tau²=0.014 Q(Chisquare)=2.23(p=0.332); I²=10.13%
# Overall effect test: z=0.69, p=0.492
#
# A-1438G Model 2: AA vs. AG + GG, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Choi_2004  165        189        109        148
# Zhang_2016 437        546        674        840
# Tencomnao_2010 70         180        67         183
# Terayama_2003 30         39         83         112
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Choi_2004  337     2.46[1.40 4.32]    22.64
# Zhang_2016 1386    0.99[0.75 1.29]    35.01
# Tencomnao_2010 363     1.10[0.72 1.68]    28.23
# Terayama_2003 151     1.16[0.49 2.74]    14.13
# Total OR   2237    1.28[0.86 1.90]      100
# 4 studies included (N=2237)
# Heterogeneity: Tau²=0.097 Q(Chisquare)=8.27(p=0.041); I²=63.71%
# Overall effect test: z=1.23, p=0.221
#
# A-1438G Model 2: AA vs. AG + GG, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  65         80         68         80
# Yusup_2013 132        195        32         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.76[0.33 1.76]    37.97
# Yusup_2013 245     1.18[0.61 2.26]    62.03
# Total OR   405     1.00[0.60 1.67]      100
# 2 studies included (N=405)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=0.64(p=0.425); I²=0%
# Overall effect test: z=0.00, p=1.000

# %%
#Calculations for recessive model of rs6311
A_minor_mod3 = [                                    #Values for a minor allele subgroup of rs6311
    "Basu_2019,29,80,30,80",
    "Bonnier_2002,21,65,58,142",
    "Choi_2004,48,189,27,148",
    "Illi_2009,34,86,172,395",
    "Noskova_2009,82,174,125,328",
#    "Ohara_1998,17,67,39,106",                      Not in HWE
    "Zhang_2016,183,546,251,840"]
G_minor_mod3 = [                                    #Values for g minor allele subgroup of rs6311
    "Tencomnao_2010,1,180,3,183",
    "Terayama_2003,14,39,22,112",
#    "Yang_2019,68,278,58,287",                      Not in HWE
    "Yusup_2013,20,195,11,50"]
caucasian_A1438G_mod3 = [                           #Values for caucasian subgroup of rs6311
    "Bonnier_2002,21,65,58,142",
    "Illi_2009,34,86,172,395",
    "Noskova_2009,82,174,125,328"]
asian_A1438G_mod3 = [                               #Values for asian subgroup of rs6311
    "Choi_2004,48,189,27,148",
#    "Ohara_1998,17,67,39,106",                      Not in HWE
    "Zhang_2016,183,546,251,840",
    "Tencomnao_2010,1,180,3,183",
    "Terayama_2003,14,39,22,112"
#    "Yang_2019,68,278,58,287"                       Not in HWE
]
other_A1438G_mod3 = [                               #Values for other subgroup of rs6311 (not included in final article)
    "Basu_2019,29,80,30,80",
    "Yusup_2013,20,195,11,50"]
A1438G_mod3 = A_minor_mod3 + G_minor_mod3
print("A-1438G Model 3: AA + AG vs. GG")
main(A1438G_mod3, settings)
print("A-1438G Model 3: AA + AG vs. GG, A as minor allele")
main(A_minor_mod3, settings)
print("A-1438G Model 3: AA + AG vs. GG, G as minor allele")
main(G_minor_mod3, settings)
print("A-1438G Model 3: AA + AG vs. GG, caucasian subgroup")
main(caucasian_A1438G_mod3, settings)
print("A-1438G Model 3: AA + AG vs. GG, asian subgroup")
main(asian_A1438G_mod3, settings)
print("A-1438G Model 3: AA + AG vs. GG, other subgroup")
main(other_A1438G_mod3, settings)
# Out:
# A-1438G Model 3: AA + AG vs. GG
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         80         30         80
# Bonnier_2002 21         65         58         142
# Choi_2004  48         189        27         148
# Illi_2009  34         86         172        395
# Noskova_2009 82         174        125        328
# Zhang_2016 183        546        251        840
# Tencomnao_2010 1          180        3          183
# Terayama_2003 14         39         22         112
# Yusup_2013 20         195        11         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.95[0.50 1.80]    10.10
# Bonnier_2002 207     0.69[0.37 1.28]    10.55
# Choi_2004  337     1.53[0.90 2.59]    12.39
# Illi_2009  481     0.85[0.53 1.36]    13.69
# Noskova_2009 502     1.45[1.00 2.10]    16.45
# Zhang_2016 1386    1.18[0.94 1.49]    20.43
# Tencomnao_2010 363     0.34[0.03 3.25]     1.31
# Terayama_2003 151     2.29[1.03 5.12]     7.61
# Yusup_2013 245     0.41[0.18 0.91]     7.48
# Total OR   3832    1.06[0.81 1.39]      100
# 9 studies included (N=3832)
# Heterogeneity: Tau²=0.078 Q(Chisquare)=17.38(p=0.027); I²=53.97%
# Overall effect test: z=0.45, p=0.653
#
# A-1438G Model 3: AA + AG vs. GG, A as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         80         30         80
# Bonnier_2002 21         65         58         142
# Choi_2004  48         189        27         148
# Illi_2009  34         86         172        395
# Noskova_2009 82         174        125        328
# Zhang_2016 183        546        251        840
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.95[0.50 1.80]     9.06
# Bonnier_2002 207     0.69[0.37 1.28]     9.66
# Choi_2004  337     1.53[0.90 2.59]    12.37
# Illi_2009  481     0.85[0.53 1.36]    14.60
# Noskova_2009 502     1.45[1.00 2.10]    20.54
# Zhang_2016 1386    1.18[0.94 1.49]    33.78
# Total OR   3073    1.13[0.91 1.39]      100
# 6 studies included (N=3073)
# Heterogeneity: Tau²=0.020 Q(Chisquare)=7.15(p=0.211); I²=30.07%
# Overall effect test: z=1.12, p=0.267
#
# A-1438G Model 3: AA + AG vs. GG, G as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Tencomnao_2010 1          180        3          183
# Terayama_2003 14         39         22         112
# Yusup_2013 20         195        11         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Tencomnao_2010 363     0.34[0.03 3.25]    20.62
# Terayama_2003 151     2.29[1.03 5.12]    39.76
# Yusup_2013 245     0.41[0.18 0.91]    39.62
# Total OR   759     0.78[0.19 3.12]      100
# 3 studies included (N=759)
# Heterogeneity: Tau²=1.099 Q(Chisquare)=9.62(p=0.008); I²=79.2%
# Overall effect test: z=0.36, p=0.721
#
# A-1438G Model 3: AA + AG vs. GG, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bonnier_2002 21         65         58         142
# Illi_2009  34         86         172        395
# Noskova_2009 82         174        125        328
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bonnier_2002 207     0.69[0.37 1.28]    26.88
# Illi_2009  481     0.85[0.53 1.36]    33.72
# Noskova_2009 502     1.45[1.00 2.10]    39.40
# Total OR   1190    0.99[0.63 1.56]      100
# 3 studies included (N=1190)
# Heterogeneity: Tau²=0.100 Q(Chisquare)=5.38(p=0.068); I²=62.8%
# Overall effect test: z=0.04, p=0.968
#
# A-1438G Model 3: AA + AG vs. GG, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Choi_2004  48         189        27         148
# Zhang_2016 183        546        251        840
# Tencomnao_2010 1          180        3          183
# Terayama_2003 14         39         22         112
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Choi_2004  337     1.53[0.90 2.59]    26.27
# Zhang_2016 1386    1.18[0.94 1.49]    57.59
# Tencomnao_2010 363     0.34[0.03 3.25]     2.08
# Terayama_2003 151     2.29[1.03 5.12]    14.06
# Total OR   2237    1.35[0.97 1.88]      100
# 4 studies included (N=2237)
# Heterogeneity: Tau²=0.036 Q(Chisquare)=4.21(p=0.244); I²=28.79%
# Overall effect test: z=1.78, p=0.075
#
# A-1438G Model 3: AA + AG vs. GG, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         80         30         80
# Yusup_2013 20         195        11         50
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  160     0.95[0.50 1.80]    54.49
# Yusup_2013 245     0.41[0.18 0.91]    45.51
# Total OR   405     0.64[0.28 1.48]      100
# 2 studies included (N=405)
# Heterogeneity: Tau²=0.221 Q(Chisquare)=2.58(p=0.112); I²=61.26%
# Overall effect test: z=1.04, p=0.298

# %%
#Calculations for homozygous model of rs6311
A_minor_mod4 = [                                    #Values for a minor allele subgroup of rs6311
    "Basu_2019,29,44,30,42",
    "Bonnier_2002,21,31,58,78",
    "Choi_2004,48,72,27,66",
    "Illi_2009,34,45,172,217",
    "Noskova_2009,82,99,125,174",
#    "Ohara_1998,17,37,39,64",                       Not in HWE
    "Zhang_2016,183,292,251,417"]
G_minor_mod4 = [                                    #Values for g minor allele subgroup of rs6311
    "Tencomnao_2010,1,111,3,119",
    "Terayama_2003,14,23,22,51",
#    "Yang_2019,68,150,58,123",                      Not in HWE
    "Yusup_2013,20,83,11,29"]
caucasian_A1438G_mod4 = [                           #Values for caucasian subgroup of rs6311
    "Bonnier_2002,21,31,58,78",
    "Illi_2009,34,45,172,217",
    "Noskova_2009,82,99,125,174"]
asian_A1438G_mod4 = [                               #Values for asian subgroup of rs6311
    "Choi_2004,48,72,27,66",
#    "Ohara_1998,17,37,39,64",                       Not in HWE
    "Zhang_2016,183,292,251,417",
    "Tencomnao_2010,1,111,3,119",
    "Terayama_2003,14,23,22,51"
#    "Yang_2019,68,150,58,123"                       Not in HWE
]
other_A1438G_mod4 = [                               #Values for other subgroup of rs6311 (not included in final article)
    "Basu_2019,29,44,30,42",
    "Yusup_2013,20,83,11,29"]
A1438G_mod4 = A_minor_mod4 + G_minor_mod4
print("A-1438G Model 4: AA vs. GG")
main(A1438G_mod4, settings)
print("A-1438G Model 4: AA vs. GG, A as minor allele")
main(A_minor_mod4, settings)
print("A-1438G Model 4: AA vs. GG, G as minor allele")
main(G_minor_mod4, settings)
print("A-1438G Model 4: AA vs. GG, caucasian subgroup")
main(caucasian_A1438G_mod4, settings)
print("A-1438G Model 4: AA vs. GG, asian subgroup")
main(asian_A1438G_mod4, settings)
print("A-1438G Model 4: AA vs. GG, other subgroup")
main(other_A1438G_mod4, settings)
# Out:
# A-1438G Model 4: AA vs. GG
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         44         30         42
# Bonnier_2002 21         31         58         78
# Choi_2004  48         72         27         66
# Illi_2009  34         45         172        217
# Noskova_2009 82         99         125        174
# Zhang_2016 183        292        251        417
# Tencomnao_2010 1          111        3          119
# Terayama_2003 14         23         22         51
# Yusup_2013 20         83         11         29
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  86      0.77[0.31 1.93]     9.70
# Bonnier_2002 109     0.72[0.29 1.80]     9.78
# Choi_2004  138     2.89[1.44 5.78]    12.96
# Illi_2009  262     0.81[0.38 1.72]    11.96
# Noskova_2009 273     1.89[1.02 3.51]    14.30
# Zhang_2016 709     1.11[0.82 1.51]    20.44
# Tencomnao_2010 230     0.35[0.04 3.43]     2.37
# Terayama_2003 74      2.05[0.75 5.60]     8.65
# Yusup_2013 112     0.52[0.21 1.28]     9.84
# Total OR   1993    1.15[0.80 1.67]      100
# 9 studies included (N=1993)
# Heterogeneity: Tau²=0.150 Q(Chisquare)=17.10(p=0.029); I²=53.22%
# Overall effect test: z=0.75, p=0.457
#
# A-1438G Model 4: AA vs. GG, A as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         44         30         42
# Bonnier_2002 21         31         58         78
# Choi_2004  48         72         27         66
# Illi_2009  34         45         172        217
# Noskova_2009 82         99         125        174
# Zhang_2016 183        292        251        417
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  86      0.77[0.31 1.93]    12.00
# Bonnier_2002 109     0.72[0.29 1.80]    12.10
# Choi_2004  138     2.89[1.44 5.78]    16.28
# Illi_2009  262     0.81[0.38 1.72]    14.95
# Noskova_2009 273     1.89[1.02 3.51]    18.08
# Zhang_2016 709     1.11[0.82 1.51]    26.60
# Total OR   1577    1.24[0.83 1.85]      100
# 6 studies included (N=1577)
# Heterogeneity: Tau²=0.134 Q(Chisquare)=11.59(p=0.041); I²=56.85%
# Overall effect test: z=1.04, p=0.298
#
# A-1438G Model 4: AA vs. GG, G as minor allele
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Tencomnao_2010 1          111        3          119
# Terayama_2003 14         23         22         51
# Yusup_2013 20         83         11         29
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Tencomnao_2010 230     0.35[0.04 3.43]    16.68
# Terayama_2003 74      2.05[0.75 5.60]    40.26
# Yusup_2013 112     0.52[0.21 1.28]    43.06
# Total OR   416     0.85[0.28 2.52]      100
# 3 studies included (N=416)
# Heterogeneity: Tau²=0.507 Q(Chisquare)=4.66(p=0.098); I²=57.06%
# Overall effect test: z=0.30, p=0.764
#
# A-1438G Model 4: AA vs. GG, caucasian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Bonnier_2002 21         31         58         78
# Illi_2009  34         45         172        217
# Noskova_2009 82         99         125        174
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Bonnier_2002 109     0.72[0.29 1.80]    27.49
# Illi_2009  262     0.81[0.38 1.72]    33.23
# Noskova_2009 273     1.89[1.02 3.51]    39.28
# Total OR   644     1.10[0.58 2.07]      100
# 3 studies included (N=644)
# Heterogeneity: Tau²=0.170 Q(Chisquare)=4.31(p=0.121); I²=53.57%
# Overall effect test: z=0.28, p=0.780
#
# A-1438G Model 4: AA vs. GG, asian subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Choi_2004  48         72         27         66
# Zhang_2016 183        292        251        417
# Tencomnao_2010 1          111        3          119
# Terayama_2003 14         23         22         51
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Choi_2004  138     2.89[1.44 5.78]    30.01
# Zhang_2016 709     1.11[0.82 1.51]    41.01
# Tencomnao_2010 230     0.35[0.04 3.43]     7.03
# Terayama_2003 74      2.05[0.75 5.60]    21.96
# Total OR   1151    1.56[0.81 3.01]      100
# 4 studies included (N=1151)
# Heterogeneity: Tau²=0.250 Q(Chisquare)=8.15(p=0.043); I²=63.19%
# Overall effect test: z=1.33, p=0.187
#
# A-1438G Model 4: AA vs. GG, other subgroup
# Study ID   Experiment Group     Control Group
#            e1         n1         e2         n2
# Basu_2019  29         44         30         42
# Yusup_2013 20         83         11         29
#
# Random IV OR
# Study ID   n       OR[95% CI]         Weight(%)
# Basu_2019  86      0.77[0.31 1.93]    49.36
# Yusup_2013 112     0.52[0.21 1.28]    50.64
# Total OR   198     0.63[0.33 1.20]      100
# 2 studies included (N=198)
# Heterogeneity: Tau²=0.000 Q(Chisquare)=0.37(p=0.548); I²=0%
# Overall effect test: z=1.40, p=0.168
